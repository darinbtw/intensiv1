# %%
import pandas as pd
import numpy
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %%
df = pd.read_csv('ml_6k copy.csv')
df
# Out:
#                                  author        author_type  \
# 0                          ID 115709096          homeowner
# 1     Самолёт плюс Подмосковье Серпухов  real_estate_agent
# 2                            ID 3246838            realtor
# 3                           ID 64398571            unknown
# 4                             ЛИДЕРМЭЙН  real_estate_agent
# ...                                 ...                ...
# 6099                        ID 67561059          homeowner
# 6100                 Виталий Костомаров            realtor
# 6101                       ID 103496464          homeowner
# 6102                        Три Ступени  real_estate_agent
# 6103              Эволюция недвижимости  real_estate_agent
#
#                                                    url     location deal_type  \
# 0       https://serpukhov.cian.ru/sale/flat/301136001/     Серпухов      sale
# 1       https://serpukhov.cian.ru/sale/flat/305145433/     Серпухов      sale
# 2       https://serpukhov.cian.ru/sale/flat/308145954/     Серпухов      sale
# 3       https://serpukhov.cian.ru/sale/flat/309086009/     Серпухов      sale
# 4       https://serpukhov.cian.ru/sale/flat/308401669/     Серпухов      sale
# ...                                                ...          ...       ...
# 6099  https://volokolamsk.cian.ru/sale/flat/307772273/  Волоколамск      sale
# 6100  https://volokolamsk.cian.ru/sale/flat/304094436/  Волоколамск      sale
# 6101  https://volokolamsk.cian.ru/sale/flat/297729371/  Волоколамск      sale
# 6102        https://istra.cian.ru/sale/flat/301549123/  Волоколамск      sale
# 6103        https://istra.cian.ru/sale/flat/307205130/  Волоколамск      sale
#
#      accommodation_type floor floors_count rooms_count total_meters  ...  \
# 0                  flat     6            6           1         20.7  ...
# 1                  flat     1            9           1         33.0  ...
# 2                  flat     4            4           1         14.0  ...
# 3                  flat     5            5           1         17.5  ...
# 4                  flat     4            7           1         25.9  ...
# ...                 ...   ...          ...         ...          ...  ...
# 6099               flat     4            4           3         55.2  ...
# 6100               flat     4            5           3         51.5  ...
# 6101               flat     7           10           3         79.9  ...
# 6102               flat     4            4          -1         59.9  ...
# 6103               flat     1            3           3         50.2  ...
#
#      finish_type living_meters kitchen_meters        phone ceiling_height  \
# 0             -1         18 м²           1 м²  79175096253            3 м
# 1             -1         18 м²           6 м²  79645530086          2,7 м
# 2             -1            -1             -1  79807126116             -1
# 3             -1            -1             -1  79645652380             -1
# 4             -1         20 м²           5 м²  79099408093          3,5 м
# ...          ...           ...            ...          ...            ...
# 6099          -1       47,2 м²           6 м²  79162535842          2,5 м
# 6100          -1       34,8 м²           6 м²  79151931107          2,5 м
# 6101          -1            -1          10 м²  79647822181          2,7 м
# 6102          -1         39 м²          10 м²  79807501795          2,7 м
# 6103          -1         38 м²           6 м²  79167314180             -1
#
#                      district                          street house_number  \
# 0                    Серпухов                         Крюкова            4
# 1                         NaN                      Ворошилова          144
# 2     Красный Текстильщик мкр             Красный Текстильщик            2
# 3                    Серпухов                     Российская            40
# 4                    Серпухов                         Химиков            8
# ...                       ...                             ...          ...
# 6099              Волоколамск                       Школьная             2
# 6100              Волоколамск                   Рижское шоссе         7/18
# 6101              Волоколамск                    Пороховская            20
# 6102                      NaN  проспект Генерала Белобородова            9
# 6103                      NaN                             NaN          NaN
#
#      underground residential_complex
# 0            NaN                 NaN
# 1         Аннино                 NaN
# 2            NaN                 NaN
# 3            NaN                 NaN
# 4            NaN                 NaN
# ...          ...                 ...
# 6099         NaN                 NaN
# 6100         NaN                 NaN
# 6101         NaN           Лама-Парк
# 6102    Нахабино                 NaN
# 6103         NaN                 NaN
#
# [6104 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6104 entries, 0 to 6103
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   author                5605 non-null   object
#  1   author_type           5608 non-null   object
#  2   url                   5888 non-null   object
#  3   location              5888 non-null   object
#  4   deal_type             5888 non-null   object
#  5   accommodation_type    5888 non-null   object
#  6   floor                 5888 non-null   object
#  7   floors_count          5888 non-null   object
#  8   rooms_count           5888 non-null   object
#  9   total_meters          5888 non-null   object
#  10  price                 5875 non-null   object
#  11  year_of_construction  5888 non-null   object
#  12  object_type           5888 non-null   object
#  13  have_loggia           5888 non-null   object
#  14  parking_type          5888 non-null   object
#  15  house_material_type   5888 non-null   object
#  16  heating_type          5888 non-null   object
#  17  finish_type           5888 non-null   object
#  18  living_meters         5888 non-null   object
#  19  kitchen_meters        5888 non-null   object
#  20  phone                 5888 non-null   object
#  21  ceiling_height        5888 non-null   object
#  22  district              2549 non-null   object
#  23  street                4629 non-null   object
#  24  house_number          4996 non-null   object
#  25  underground           4023 non-null   object
#  26  residential_complex   2970 non-null   object
# dtypes: object(27)
# memory usage: 1.3+ MB

# %%
df['location'].unique()
# Out:
# array(['Серпухов', 'Дубна', 'Москва', 'Яхрома', 'Яхромаа', 'Воскресенск',
#        'Талдом', 'Руза', 'Реутов', 'Краснозаводск', 'Одинцово', 'Люберцы',
#        'Ивантеевка', 'Котельники', 'Электросталь', 'Долгопрудный',
#        'Лобня', 'Химки', 'Хотьково', 'Балашиха', 'Домодедово',
#        'Раменское', 'Бекасово', 'Звенигород', 'Дмитров', nan, 'Ногинск',
#        'Троицк', 'location', 'Щёлково', 'Королёв', 'Клин', 'Черноголовка',
#        'Видное', 'Волоколамск'], dtype=object)

# %%
print(df.describe())
# Out:
#          author        author_type                                        url  \
# count      5605               5608                                       5888
# unique     2260                  8                                       5007
# top     Самолет  real_estate_agent  https://krym.cian.ru/sale/flat/292124957/
# freq        143               2638                                          7
#
#         location deal_type accommodation_type floor floors_count rooms_count  \
# count       5888      5888               5888  5888         5888        5888
# unique        34         2                  2    55           73           7
# top     Балашиха      sale               flat     2            5           1
# freq        1211      5887               5887   850          911        2864
#
#        total_meters  ... finish_type living_meters kitchen_meters  \
# count          5888  ...        5888          5888           5888
# unique         1355  ...          27           555            280
# top            40.0  ...          -1            -1             -1
# freq             63  ...        4405          1383           1086
#
#               phone ceiling_height district    street house_number  \
# count          5888           5888     2549      4629         4996
# unique         3411            108      364      1193          868
# top     78005116552             -1  Дмитров   Яганова            2
# freq            122           2133      128        79          166
#
#        underground residential_complex
# count         4023                2970
# unique         304                 860
# top     Щёлковская    Новоград Павлино
# freq           506                 114
#
# [4 rows x 27 columns]

# %%
import seaborn as sns

sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# author                   499
# author_type              496
# url                      216
# location                 216
# deal_type                216
# accommodation_type       216
# floor                    216
# floors_count             216
# rooms_count              216
# total_meters             216
# price                    229
# year_of_construction     216
# object_type              216
# have_loggia              216
# parking_type             216
# house_material_type      216
# heating_type             216
# finish_type              216
# living_meters            216
# kitchen_meters           216
# phone                    216
# ceiling_height           216
# district                3555
# street                  1475
# house_number            1108
# underground             2081
# residential_complex     3134
# dtype: int64

# %%
# df.dropna(inplace=True)

# %%
def get_numerical_summary(df):
    total = df.shape[0]
    missing_columns = [col for col in df.columns if df[col].isnull().sum() > 0]
    missing_percent = {}
    for col in missing_columns:
        null_count = df[col].isnull().sum()
        per = (null_count/total) * 100
        missing_percent[col] = per
        print("{} : {} ({}%)".format(col, null_count, round(per, 3)))
    return missing_percent

# %%
missing_percent = get_numerical_summary(df)
# Out:
# author : 499 (8.175%)
# author_type : 496 (8.126%)
# url : 216 (3.539%)
# location : 216 (3.539%)
# deal_type : 216 (3.539%)
# accommodation_type : 216 (3.539%)
# floor : 216 (3.539%)
# floors_count : 216 (3.539%)
# rooms_count : 216 (3.539%)
# total_meters : 216 (3.539%)
# price : 229 (3.752%)
# year_of_construction : 216 (3.539%)
# object_type : 216 (3.539%)
# have_loggia : 216 (3.539%)
# parking_type : 216 (3.539%)
# house_material_type : 216 (3.539%)
# heating_type : 216 (3.539%)
# finish_type : 216 (3.539%)
# living_meters : 216 (3.539%)
# kitchen_meters : 216 (3.539%)
# phone : 216 (3.539%)
# ceiling_height : 216 (3.539%)
# district : 3555 (58.24%)
# street : 1475 (24.164%)
# house_number : 1108 (18.152%)
# underground : 2081 (34.092%)
# residential_complex : 3134 (51.343%)

# %%
msno.matrix(df)
plt.figure(figsize=(15,9))
plt.show()

# %%
df_cleaned = df.dropna(thresh=2)

# %%
msno.matrix(df_cleaned)
plt.figure(figsize=(15,9))
plt.show()

# %%
missing_percent = get_numerical_summary(df_cleaned)
# Out:
# author : 283 (4.806%)
# author_type : 280 (4.755%)
# price : 13 (0.221%)
# district : 3339 (56.709%)
# street : 1259 (21.382%)
# house_number : 892 (15.149%)
# underground : 1865 (31.675%)
# residential_complex : 2918 (49.558%)

# %%
msno.heatmap(df_cleaned, labels = True)
# Out:
# <Axes: >
