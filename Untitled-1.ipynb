# %%
import pandas as pd
import numpy
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('main_file.csv', sep=';')
df
# Out:
#                author        author_type  \
# 0                 NaN                NaN
# 1         ID 62993603            unknown
# 2            Альфалот  real_estate_agent
# 3                 NaN                NaN
# 4        Этажи Москва  real_estate_agent
# ..                ...                ...
# 379   PROнедвижимость  real_estate_agent
# 380  Светлана Сандина            realtor
# 381               NaN                NaN
# 382       ID 62993603            unknown
# 383          Альфалот  real_estate_agent
#
#                                                   url      location deal_type  \
# 0    https://dolgoprudny.cian.ru/sale/flat/292660187/  Долгопрудный      sale
# 1    https://dolgoprudny.cian.ru/sale/flat/309018951/  Долгопрудный      sale
# 2    https://dolgoprudny.cian.ru/sale/flat/308775890/  Долгопрудный      sale
# 3    https://dolgoprudny.cian.ru/sale/flat/308076041/  Долгопрудный      sale
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384 entries, 0 to 383
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   author                356 non-null    object
#  1   author_type           356 non-null    object
#  2   url                   384 non-null    object
#  3   location              384 non-null    object
#  4   deal_type             384 non-null    object
#  5   accommodation_type    384 non-null    object
#  6   floor                 384 non-null    int64
#  7   floors_count          384 non-null    int64
#  8   rooms_count           384 non-null    int64
#  9   total_meters          384 non-null    float64
#  10  price                 384 non-null    int64
#  11  year_of_construction  384 non-null    object
#  12  object_type           384 non-null    object
#  13  have_loggia           384 non-null    object
#  14  parking_type          384 non-null    object
# ...

# %%
df['location'].unique()
# Out:
# array(['Долгопрудный', 'Электросталь', 'Москва'], dtype=object)

# %%
import seaborn as sns

sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >
