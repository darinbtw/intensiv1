# %%
import pandas as pd
import numpy
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %%
df = pd.read_csv('ml_6k.csv')
df
# Out:
#                                  author        author_type  \
# 0                          ID 115709096          homeowner
# 1     Самолёт плюс Подмосковье Серпухов  real_estate_agent
# 2                            ID 3246838            realtor
# 3                           ID 64398571            unknown
# 4                             ЛИДЕРМЭЙН  real_estate_agent
# ...                                 ...                ...
# 5883                        ID 67561059          homeowner
# 5884                 Виталий Костомаров            realtor
# 5885                       ID 103496464          homeowner
# 5886                        Три Ступени  real_estate_agent
# 5887              Эволюция недвижимости  real_estate_agent
#
#                                                    url     location deal_type  \
# 0       https://serpukhov.cian.ru/sale/flat/301136001/     Серпухов      sale
# 1       https://serpukhov.cian.ru/sale/flat/305145433/     Серпухов      sale
# 2       https://serpukhov.cian.ru/sale/flat/308145954/     Серпухов      sale
# 3       https://serpukhov.cian.ru/sale/flat/309086009/     Серпухов      sale
# 4       https://serpukhov.cian.ru/sale/flat/308401669/     Серпухов      sale
# ...                                                ...          ...       ...
# 5883  https://volokolamsk.cian.ru/sale/flat/307772273/  Волоколамск      sale
# 5884  https://volokolamsk.cian.ru/sale/flat/304094436/  Волоколамск      sale
# 5885  https://volokolamsk.cian.ru/sale/flat/297729371/  Волоколамск      sale
# 5886        https://istra.cian.ru/sale/flat/301549123/  Волоколамск      sale
# 5887        https://istra.cian.ru/sale/flat/307205130/  Волоколамск      sale
#
#      accommodation_type floor floors_count rooms_count total_meters  ...  \
# 0                  flat     6            6           1         20.7  ...
# 1                  flat     1            9           1         33.0  ...
# 2                  flat     4            4           1         14.0  ...
# 3                  flat     5            5           1         17.5  ...
# 4                  flat     4            7           1         25.9  ...
# ...                 ...   ...          ...         ...          ...  ...
# 5883               flat     4            4           3         55.2  ...
# 5884               flat     4            5           3         51.5  ...
# 5885               flat     7           10           3         79.9  ...
# 5886               flat     4            4          -1         59.9  ...
# 5887               flat     1            3           3         50.2  ...
#
#      finish_type living_meters kitchen_meters        phone ceiling_height  \
# 0             -1         18 м²           1 м²  79175096253            3 м
# 1             -1         18 м²           6 м²  79645530086          2,7 м
# 2             -1            -1             -1  79807126116             -1
# 3             -1            -1             -1  79645652380             -1
# 4             -1         20 м²           5 м²  79099408093          3,5 м
# ...          ...           ...            ...          ...            ...
# 5883          -1       47,2 м²           6 м²  79162535842          2,5 м
# 5884          -1       34,8 м²           6 м²  79151931107          2,5 м
# 5885          -1            -1          10 м²  79647822181          2,7 м
# 5886          -1         39 м²          10 м²  79807501795          2,7 м
# 5887          -1         38 м²           6 м²  79167314180             -1
#
#                      district                          street house_number  \
# 0                    Серпухов                         Крюкова            4
# 1                         NaN                      Ворошилова          144
# 2     Красный Текстильщик мкр             Красный Текстильщик            2
# 3                    Серпухов                     Российская            40
# 4                    Серпухов                         Химиков            8
# ...                       ...                             ...          ...
# 5883              Волоколамск                       Школьная             2
# 5884              Волоколамск                   Рижское шоссе         7/18
# 5885              Волоколамск                    Пороховская            20
# 5886                      NaN  проспект Генерала Белобородова            9
# 5887                      NaN                             NaN          NaN
#
#      underground residential_complex
# 0            NaN                 NaN
# 1         Аннино                 NaN
# 2            NaN                 NaN
# 3            NaN                 NaN
# 4            NaN                 NaN
# ...          ...                 ...
# 5883         NaN                 NaN
# 5884         NaN                 NaN
# 5885         NaN           Лама-Парк
# 5886    Нахабино                 NaN
# 5887         NaN                 NaN
#
# [5888 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5888 entries, 0 to 5887
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   author                5605 non-null   object
#  1   author_type           5608 non-null   object
#  2   url                   5888 non-null   object
#  3   location              5888 non-null   object
#  4   deal_type             5888 non-null   object
#  5   accommodation_type    5888 non-null   object
#  6   floor                 5888 non-null   object
#  7   floors_count          5888 non-null   object
#  8   rooms_count           5888 non-null   object
#  9   total_meters          5888 non-null   object
#  10  price                 5875 non-null   object
#  11  year_of_construction  5888 non-null   object
#  12  object_type           5888 non-null   object
#  13  have_loggia           5888 non-null   object
#  14  parking_type          5888 non-null   object
#  15  house_material_type   5888 non-null   object
#  16  heating_type          5888 non-null   object
#  17  finish_type           5888 non-null   object
#  18  living_meters         5888 non-null   object
#  19  kitchen_meters        5888 non-null   object
#  20  phone                 5888 non-null   object
#  21  ceiling_height        5888 non-null   object
#  22  district              2549 non-null   object
#  23  street                4629 non-null   object
#  24  house_number          4996 non-null   object
#  25  underground           4023 non-null   object
#  26  residential_complex   2970 non-null   object
# dtypes: object(27)
# memory usage: 1.2+ MB

# %%
df['location'].unique()
# Out:
# array(['Серпухов', 'Дубна', 'Москва', 'Яхрома', 'Яхромаа', 'Воскресенск',
#        'Талдом', 'Руза', 'Реутов', 'Краснозаводск', 'Одинцово', 'Люберцы',
#        'Ивантеевка', 'Котельники', 'Электросталь', 'Долгопрудный',
#        'Лобня', 'Химки', 'Хотьково', 'Балашиха', 'Домодедово',
#        'Раменское', 'Бекасово', 'Звенигород', 'Дмитров', 'Ногинск',
#        'Троицк', 'location', 'Щёлково', 'Королёв', 'Клин', 'Черноголовка',
#        'Видное', 'Волоколамск'], dtype=object)

# %%
columns = list(df.columns)
print(columns)
df = df.drop(['author', 'author_type', 'url', 'phone', 'deal_type', 'accommodation_type', 'house_number'], axis=1)
columns = list(df.columns)
print(columns)
# Out:
# ['author', 'author_type', 'url', 'location', 'deal_type', 'accommodation_type', 'floor', 'floors_count', 'rooms_count', 'total_meters', 'price', 'year_of_construction', 'object_type', 'have_loggia', 'parking_type', 'house_material_type', 'heating_type', 'finish_type', 'living_meters', 'kitchen_meters', 'phone', 'ceiling_height', 'district', 'street', 'house_number', 'underground', 'residential_complex']
# ['location', 'floor', 'floors_count', 'rooms_count', 'total_meters', 'price', 'year_of_construction', 'object_type', 'have_loggia', 'parking_type', 'house_material_type', 'heating_type', 'finish_type', 'living_meters', 'kitchen_meters', 'ceiling_height', 'district', 'street', 'underground', 'residential_complex']

# %%
df.head(40)
# Out:
#     location floor floors_count rooms_count total_meters     price  \
# 0   Серпухов     6            6           1         20.7   2350000
# 1   Серпухов     1            9           1         33.0   4150000
# 2   Серпухов     4            4           1         14.0   1700000
# 3   Серпухов     5            5           1         17.5   2500000
# 4   Серпухов     4            7           1         25.9   3000000
# 5   Серпухов     2            3           1         46.7   6599999
# 6   Серпухов     3            5           1         29.0   3350000
# 7   Серпухов     3            6           1         19.1   3600000
# 8   Серпухов     1            2           1         27.1   1900000
# 9   Серпухов     6            9           2         42.7   3990000
# 10  Серпухов     1            5           2         42.8   2999000
# 11  Серпухов     3            4          -1         47.0   1980000
# 12  Серпухов    15           17           1        20.55   2600000
# 13  Серпухов     1            3           1         25.3   2500000
# 14  Серпухов     2            3           1         36.0   2790000
# 15  Серпухов     1            3           1         22.4   2600000
# 16  Серпухов     2            3           2         42.0   3200000
# 17  Серпухов     2            4           1         41.4   2800000
# 18  Серпухов     2            2           1         31.3   2700000
# 19  Серпухов     5            5           1         31.0   3090000
# 20  Серпухов     1            2           1         32.1   2600000
# 21  Серпухов     2            5           2         47.5   2600000
# 22  Серпухов     2            3           1         27.0   2500000
# 23  Серпухов     6            6           1         38.9   2800000
# 24  Серпухов     2            5           1         29.0   3100000
# 25  Серпухов     1            2           3        141.9   3081000
# 26  Серпухов     8           10           3         64.0   7450000
# 27  Серпухов     8            9           3         60.0   6600000
# 28  Серпухов     3           10           3         62.1   7300000
# 29  Серпухов     3            5           3         67.2   7999000
# 30  Серпухов     7           24           3         77.6  12700000
# 31  Серпухов     6            9           3         62.0   7350000
# 32  Серпухов     5           10           3         63.0   7600000
# 33  Серпухов     1            5           3         57.9   5750000
# 34  Серпухов     1            2           3         56.0   5490000
# 35  Серпухов     7           10           3         65.0   8800000
# 36  Серпухов     2            5           3         54.0   5400000
# 37  Серпухов     1            5           3         67.0   8300000
# 38  Серпухов     6            9           2         42.7   3990000
# 39  Серпухов     4            5           2         45.5   5380000
#
#    year_of_construction             object_type have_loggia parking_type  \
# 0                  1917                Вторичка          -1     Наземная
# 1                  1975                Вторичка          -1           -1
# 2                    -1                Вторичка          -1           -1
# 3                  1968                Вторичка          -1           -1
# 4                  2009                Вторичка          -1     Наземная
# 5                    -1                Вторичка          -1           -1
# 6                  1917                Вторичка          -1     Наземная
# 7                  1917                Вторичка          -1           -1
# 8                  1969                Вторичка          -1     Наземная
# 9                  1980                Вторичка    1 лоджия     Наземная
# 10                 1990                Вторичка    1 балкон     Наземная
# 11                 1964                Вторичка    1 балкон     Наземная
# 12                 2025             Новостройка    1 лоджия     Наземная
# 13                 2015                Вторичка    1 лоджия           -1
# 14                   -1                Вторичка          -1           -1
# 15                   -1                Вторичка    1 лоджия           -1
# 16                   -1                Вторичка          -1     Наземная
# 17                 1975                Вторичка    1 балкон     Наземная
# 18                 1970                Вторичка          -1     Наземная
# 19                 1984                Вторичка    1 балкон     Наземная
# 20                 1965                Вторичка          -1     Наземная
# 21                   -1                Вторичка    1 балкон     Наземная
# 22                   -1                Вторичка          -1           -1
# 23                 2010                Вторичка    1 лоджия           -1
# 24                 1964                Вторичка          -1           -1
# 25              Аукцион                Вторичка          -1           -1
# 26                 1992                Вторичка    1 лоджия     Наземная
# 27                 1975                Вторичка    1 лоджия           -1
# 28                 1992                Вторичка    1 балкон           -1
# 29                   -1                Вторичка    3 лоджии     Наземная
# 30                 2011  Вторичка / Апартаменты    1 балкон           -1
# 31                 1986                Вторичка    1 лоджия           -1
# 32                 1994                Вторичка    1 лоджия           -1
# 33                 1969                Вторичка          -1           -1
# 34                 1956                Вторичка          -1     Наземная
# 35                   -1                Вторичка          -1           -1
# 36                 1966                Вторичка          -1           -1
# 37                 1973                Вторичка    1 лоджия     Наземная
# 38                 1980                Вторичка    1 лоджия     Наземная
# 39                 1971                Вторичка    1 балкон     Наземная
#
#    house_material_type heating_type  finish_type living_meters kitchen_meters  \
# 0                   -1           -1           -1         18 м²           1 м²
# 1                   -1           -1           -1         18 м²           6 м²
# 2                   -1           -1           -1            -1             -1
# 3                   -1           -1           -1            -1             -1
# 4                   -1           -1           -1         20 м²           5 м²
# 5                   -1           -1           -1         25 м²           6 м²
# 6                   -1           -1           -1         25 м²             -1
# 7                   -1           -1           -1            -1             -1
# 8                   -1           -1           -1         18 м²           6 м²
# 9                   -1           -1           -1       29,7 м²         5,6 м²
# 10                  -1           -1           -1       24,9 м²           6 м²
# 11                  -1           -1           -1            -1          16 м²
# 12                  -1           -1  Без отделки       13,4 м²           3 м²
# 13                  -1           -1           -1       14,1 м²         6,2 м²
# 14                  -1           -1           -1            -1             -1
# 15                  -1           -1           -1            -1             -1
# 16                  -1           -1           -1         28 м²           6 м²
# 17                  -1           -1           -1         20 м²           7 м²
# 18                  -1           -1           -1            -1           5 м²
# 19                  -1           -1           -1         15 м²         7,3 м²
# 20                  -1           -1           -1            -1         6,1 м²
# 21                  -1           -1           -1         28 м²           6 м²
# 22                  -1           -1           -1         19 м²           3 м²
# 23                  -1           -1           -1         16 м²          10 м²
# 24                  -1           -1           -1         19 м²           6 м²
# 25                  -1           -1           -1            -1             -1
# 26                  -1           -1           -1            -1           9 м²
# 27                  -1           -1           -1         40 м²           9 м²
# 28                  -1           -1           -1         45 м²           9 м²
# 29                  -1           -1           -1         50 м²          10 м²
# 30                  -1           -1           -1            -1           5 м²
# 31                  -1           -1           -1         44 м²           8 м²
# 32                  -1           -1           -1            -1           8 м²
# 33                  -1           -1           -1            -1           5 м²
# 34                  -1           -1           -1         40 м²           6 м²
# 35                  -1           -1           -1            -1             -1
# 36                  -1           -1           -1         39 м²           6 м²
# 37                  -1           -1           -1         41 м²           9 м²
# 38                  -1           -1           -1       29,7 м²         5,6 м²
# 39                  -1           -1           -1       32,5 м²           6 м²
#
#    ceiling_height                 district                  street  \
# 0             3 м                 Серпухов                 Крюкова
# 1           2,7 м                      NaN              Ворошилова
# 2              -1  Красный Текстильщик мкр     Красный Текстильщик
# 3              -1                 Серпухов             Российская
# 4           3,5 м                 Серпухов                 Химиков
# 5              -1                 Серпухов          2-я Московская
# 6             3 м                 Серпухов                  Форсса
# 7              -1                 Серпухов                 Крюкова
# 8           2,5 м                      NaN                     NaN
# 9           2,7 м                 Серпухов               Весенняя
# 10          2,5 м             пос. Чехов-8                   Южная
# 11          2,9 м                      NaN   Художественный проезд
# 12             -1          мкр. Востряково               Ледовская
# 13          2,8 м             д. Ворщиково          Солнечный Град
# 14             -1                    Чехов                Русская
# 15             -1                    Чехов                Русская
# 16             -1                      NaN                     NaN
# 17             -1                      NaN                     NaN
# 18             -1                д. Рыбаки                 Садовая
# 19             -1             с. Ильинское               Бригадная
# 20          2,5 м               д. Дубнево              Новые Дома
# 21          2,4 м                      NaN                     NaN
# 22          2,5 м  Красный Текстильщик мкр     Красный Текстильщик
# 23          2,8 м              д. Городище              Молодежная
# 24          2,5 м                 Серпухов  переулок 1-й Оборонный
# 25             -1                 Серпухов              Калужская
# 26          2,8 м                 Серпухов               Звездная
# 27          2,6 м                 Серпухов              Ворошилова
# 28          2,8 м                 Серпухов               Звездная
# 29             -1                 Серпухов       Ивана Болотникова
# 30             -1                 Серпухов       Борисовское шоссе
# 31         2,65 м                 Серпухов                 Пушкина
# 32             -1                 Серпухов                  Новая
# 33             -1                 Серпухов            Центральная
# 34          2,8 м                 Серпухов               Захаркина
# 35             -1                 Серпухов               Весенняя
# 36             -1                 Серпухов              Лермонтова
# 37          2,5 м                 Серпухов             Космонавтов
# 38          2,7 м                 Серпухов               Весенняя
# 39          2,6 м                 Серпухов              Советская
#
#    underground residential_complex
# 0          NaN                 NaN
# 1       Аннино                 NaN
# 2          NaN                 NaN
# 3          NaN                 NaN
# 4          NaN                 NaN
# 5          NaN                 NaN
# 6          NaN                 NaN
# 7          NaN                 NaN
# 8          NaN                 NaN
# 9          NaN                 NaN
# 10         NaN                 NaN
# 11  Силикатная                 NaN
# 12         NaN           Солнечный
# 13         NaN                 NaN
# 14         NaN                 NaN
# 15         NaN                 NaN
# 16         NaN                 NaN
# 17         NaN                 NaN
# 18         NaN                 NaN
# 19         NaN                 NaN
# 20         NaN                 NaN
# 21         NaN                 NaN
# 22         NaN                 NaN
# 23         NaN                 NaN
# 24         NaN                 NaN
# 25         NaN                 NaN
# 26         NaN                 NaN
# 27         NaN                 NaN
# 28         NaN                 NaN
# 29         NaN                 NaN
# 30         NaN                 NaN
# 31         NaN                 NaN
# 32         NaN                 NaN
# 33         NaN                 NaN
# 34         NaN                 NaN
# 35         NaN                 NaN
# 36         NaN                 NaN
# 37         NaN                 NaN
# 38         NaN                 NaN
# 39         NaN                 NaN

# %%
print(df.describe())
# Out:
#         location floor floors_count rooms_count total_meters    price  \
# count       5888  5888         5888        5888         5888     5875
# unique        34    55           73           7         1355     2164
# top     Балашиха     2            5           1         40.0  6500000
# freq        1211   850          911        2864           63       65
#
#        year_of_construction object_type have_loggia parking_type  \
# count                  5888        5888        5888         5888
# unique                  111           7          14            6
# top                      -1    Вторичка          -1           -1
# freq                   1049        4140        2625         2714
#
#        house_material_type heating_type finish_type living_meters  \
# count                 5888         5888        5888          5888
# unique                  14            2          27           555
# top                     -1           -1          -1            -1
# freq                  4828         5887        4405          1383
#
#        kitchen_meters ceiling_height district    street underground  \
# count            5888           5888     2549      4629        4023
# unique            280            108      364      1193         304
# top                -1             -1  Дмитров   Яганова  Щёлковская
# freq             1086           2133      128        79         506
#
#        residential_complex
# count                 2970
# unique                 860
# top       Новоград Павлино
# freq                   114

# %%
import seaborn as sns

sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
def get_numerical_summary(df):
    total = df.shape[0]
    missing_columns = [col for col in df.columns if df[col].isnull().sum() > 0]
    missing_percent = {}
    for col in missing_columns:
        null_count = df[col].isnull().sum()
        per = (null_count/total) * 100
        missing_percent[col] = per
        print("{} : {} ({}%)".format(col, null_count, round(per, 3)))
    return missing_percent

# %%
missing_percent = get_numerical_summary(df)
# Out:
# price : 13 (0.221%)
# district : 3339 (56.709%)
# street : 1259 (21.382%)
# underground : 1865 (31.675%)
# residential_complex : 2918 (49.558%)

# %%
msno.matrix(df)
plt.figure(figsize=(15,9))
plt.show()

# %%
df_cleaned = df.dropna(thresh=2)

# %%
msno.matrix(df_cleaned)
plt.figure(figsize=(15,9))
plt.show()

# %%
missing_percent = get_numerical_summary(df_cleaned)
# Out:
# price : 13 (0.221%)
# district : 3339 (56.709%)
# street : 1259 (21.382%)
# underground : 1865 (31.675%)
# residential_complex : 2918 (49.558%)

# %%
msno.heatmap(df_cleaned, labels = True)
# Out:
# <Axes: >

# %%
num_duplicates = df_cleaned.duplicated().sum()

print("Всего дубликатов:", num_duplicates)
# Out:
# Всего дубликатов: 601

# %%
num_nulls_Levy=df_cleaned["author"].isnull().sum()
print("Количество пустых значений:", num_nulls_Levy)
num_nulls_Levy=df_cleaned["author_type"].isnull().sum()
print("Количество пустых значений:", num_nulls_Levy)
num_nulls_Levy=df_cleaned["street"].isnull().sum()
print("Количество пустых значений:", num_nulls_Levy)
num_nulls_Levy=df_cleaned["total_meters"].isnull().sum()
print("Количество пустых значений:", num_nulls_Levy)
num_nulls_Levy=df_cleaned["author_type"].isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Darin_btw\Documents\GitHub\parcing-cian\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'author'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[190], line 1
# ----> 1 num_nulls_Levy=df_cleaned["author"].isnull().sum()
#       2 print("Количество пустых значений:", num_nulls_Levy)
#       3 num_nulls_Levy=df_cleaned["author_type"].isnull().sum()
#
# File c:\Users\Darin_btw\Documents\GitHub\parcing-cian\.venv\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\Darin_btw\Documents\GitHub\parcing-cian\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'author'

# %%
df_cleaned.isnull().sum()
# Out:
# author                   283
# author_type              280
# url                        0
# location                   0
# floor                      0
# floors_count               0
# rooms_count                0
# total_meters               0
# price                     13
# year_of_construction       0
# object_type                0
# have_loggia                0
# parking_type               0
# house_material_type        0
# heating_type               0
# finish_type                0
# living_meters              0
# kitchen_meters             0
# phone                      0
# ceiling_height             0
# district                3339
# street                  1259
# underground             1865
# residential_complex     2918
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5888 entries, 0 to 5887
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   author                5605 non-null   object
#  1   author_type           5608 non-null   object
#  2   url                   5888 non-null   object
#  3   location              5888 non-null   object
#  4   floor                 5888 non-null   object
#  5   floors_count          5888 non-null   object
#  6   rooms_count           5888 non-null   object
#  7   total_meters          5888 non-null   object
#  8   price                 5875 non-null   object
#  9   year_of_construction  5888 non-null   object
#  10  object_type           5888 non-null   object
#  11  have_loggia           5888 non-null   object
#  12  parking_type          5888 non-null   object
#  13  house_material_type   5888 non-null   object
#  14  heating_type          5888 non-null   object
#  15  finish_type           5888 non-null   object
#  16  living_meters         5888 non-null   object
#  17  kitchen_meters        5888 non-null   object
#  18  phone                 5888 non-null   object
#  19  ceiling_height        5888 non-null   object
#  20  district              2549 non-null   object
#  21  street                4629 non-null   object
#  22  underground           4023 non-null   object
#  23  residential_complex   2970 non-null   object
# dtypes: object(24)
# memory usage: 1.1+ MB
