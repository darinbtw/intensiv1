# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('parsed.csv')
df.head()
# Out:
#                               author        author_type  \
# 0                       ID 115709096          homeowner
# 1  Самолёт плюс Подмосковье Серпухов  real_estate_agent
# 2                         ID 3246838            realtor
# 3                        ID 64398571            unknown
# 4                          ЛИДЕРМЭЙН  real_estate_agent
#
#                                               url  location deal_type  \
# 0  https://serpukhov.cian.ru/sale/flat/301136001/  Серпухов      sale
# 1  https://serpukhov.cian.ru/sale/flat/305145433/  Серпухов      sale
# 2  https://serpukhov.cian.ru/sale/flat/308145954/  Серпухов      sale
# 3  https://serpukhov.cian.ru/sale/flat/309086009/  Серпухов      sale
# 4  https://serpukhov.cian.ru/sale/flat/308401669/  Серпухов      sale
#
#   accommodation_type floor floors_count rooms_count total_meters  ...  \
# 0               flat     6            6           1         20.7  ...
# 1               flat     1            9           1         33.0  ...
# 2               flat     4            4           1         14.0  ...
# 3               flat     5            5           1         17.5  ...
# 4               flat     4            7           1         25.9  ...
#
#   finish_type living_meters kitchen_meters        phone ceiling_height  \
# 0          -1         18 м²           1 м²  79175096253            3 м
# 1          -1         18 м²           6 м²  79645530086          2,7 м
# 2          -1            -1             -1  79807126116             -1
# 3          -1            -1             -1  79645652380             -1
# 4          -1         20 м²           5 м²  79099408093          3,5 м
#
#                   district                street house_number underground  \
# 0                 Серпухов               Крюкова            4         NaN
# 1                      NaN            Ворошилова          144      Аннино
# 2  Красный Текстильщик мкр   Красный Текстильщик            2         NaN
# 3                 Серпухов           Российская            40         NaN
# 4                 Серпухов               Химиков            8         NaN
#
#   residential_complex
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 27 columns]

# %%
df.shape
# Out:
# (8393, 27)

# %%
df = df.drop_duplicates()

# %% [markdown]
# Дубликатов почему-то нет

# %%
df.head
# Out:
# <bound method NDFrame.head of                                  author        author_type  \
# 0                          ID 115709096          homeowner
# 1     Самолёт плюс Подмосковье Серпухов  real_estate_agent
# 2                            ID 3246838            realtor
# 3                           ID 64398571            unknown
# 4                             ЛИДЕРМЭЙН  real_estate_agent
# ...                                 ...                ...
# 8388                              МИЭЛЬ  real_estate_agent
# 8389                                ПИК          developer
# 8390                        ID 47276638          homeowner
# 8391                         EstateLiga  real_estate_agent
# 8392                                ПИК          developer
#
#                                                  url  location deal_type  \
# 0     https://serpukhov.cian.ru/sale/flat/301136001/  Серпухов      sale
# 1     https://serpukhov.cian.ru/sale/flat/305145433/  Серпухов      sale
# 2     https://serpukhov.cian.ru/sale/flat/308145954/  Серпухов      sale
# 3     https://serpukhov.cian.ru/sale/flat/309086009/  Серпухов      sale
# 4     https://serpukhov.cian.ru/sale/flat/308401669/  Серпухов      sale
# ...                                              ...       ...       ...
# 8388  https://mytishchi.cian.ru/sale/flat/308939371/    Мытищи      sale
# 8389  https://mytishchi.cian.ru/sale/flat/306943495/    Мытищи      sale
# 8390  https://mytishchi.cian.ru/sale/flat/294184046/    Мытищи      sale
# 8391  https://mytishchi.cian.ru/sale/flat/304572510/    Мытищи      sale
# 8392  https://mytishchi.cian.ru/sale/flat/303513303/    Мытищи      sale
#
#      accommodation_type floor floors_count rooms_count total_meters  ...  \
# 0                  flat     6            6           1         20.7  ...
# 1                  flat     1            9           1         33.0  ...
# 2                  flat     4            4           1         14.0  ...
# 3                  flat     5            5           1         17.5  ...
# 4                  flat     4            7           1         25.9  ...
# ...                 ...   ...          ...         ...          ...  ...
# 8388               flat     8           14           2         69.7  ...
# 8389               flat    19           25           2         48.1  ...
# 8390               flat     3            5           2         45.0  ...
# 8391               flat     3            6           2         34.0  ...
# 8392               flat     3           16           2         58.6  ...
#
#      finish_type living_meters kitchen_meters        phone ceiling_height  \
# 0             -1         18 м²           1 м²  79175096253            3 м
# 1             -1         18 м²           6 м²  79645530086          2,7 м
# 2             -1            -1             -1  79807126116             -1
# 3             -1            -1             -1  79645652380             -1
# 4             -1         20 м²           5 м²  79099408093          3,5 м
# ...          ...           ...            ...          ...            ...
# 8388          -1         38 м²        10,5 м²  79672094035             -1
# 8389    Чистовая       22,7 м²        16,1 м²  74951370494         2,62 м
# 8390          -1            -1           6 м²  79153266030             -1
# 8391          -1         19 м²           8 м²  79651097781         2,75 м
# 8392    Чистовая       24,9 м²        21,4 м²  74951348120         2,62 м
#
#                      district                street house_number underground  \
# 0                    Серпухов               Крюкова            4         NaN
# 1                         NaN            Ворошилова          144      Аннино
# 2     Красный Текстильщик мкр   Красный Текстильщик            2         NaN
# 3                    Серпухов           Российская            40         NaN
# 4                    Серпухов               Химиков            8         NaN
# ...                       ...                   ...          ...         ...
# 8388                      NaN            Юбилейная             6  Медведково
# 8389                      NaN                   NaN          NaN   Ростокино
# 8390                      NaN            Юбилейная          11к3  Медведково
# 8391                      NaN      бульвар Тенистый            5  Медведково
# 8392                      NaN                   NaN          NaN  Медведково
#
#          residential_complex
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 8388             Ярославский
# 8389  Ярославский квартал ЖК
# 8390                     NaN
# 8391    Императорские Мытищи
# 8392            Яуза Парк ЖК
#
# [7577 rows x 27 columns]>

# %%
df['location'].value_counts()
# Out:
# location
# Балашиха         1176
# Химки             805
# Москва            755
# Долгопрудный      476
# Котельники        415
# Пересвет          411
# Щёлково           325
# Королёв           315
# Бекасово          307
# Дмитров           259
# Электросталь      230
# Мытищи            195
# Дзержинский       169
# Клин              161
# Красногорск       142
# Троицк            106
# Домодедово        106
# Яхрома            100
# Талдом            100
# Люберцы            94
# Ивантеевка         94
# Волоколамск        86
# Видное             78
# Звенигород         76
# Фрязино            69
# Раменское          62
# Серпухов           59
# Дубна              57
# Руза               55
# Лобня              55
# москва             39
# Яхромаа            38
# Хотьково           32
# Ногинск            28
# Краснозаводск      25
# Черноголовка       23
# Реутов             15
# Воскресенск        14
# Шатура             13
# Талодом             8
# Одинцово            2
# location            1
# Name: count, dtype: int64

# %%
df['location'].unique()
# Out:
# array(['Серпухов', 'Дубна', 'Москва', 'Яхрома', 'Яхромаа', 'Воскресенск',
#        'Талдом', 'Руза', 'Реутов', 'Краснозаводск', 'Одинцово', 'Люберцы',
#        'Ивантеевка', 'Котельники', 'Электросталь', 'Долгопрудный',
#        'Лобня', 'Химки', 'Хотьково', 'Балашиха', 'Домодедово',
#        'Раменское', 'Бекасово', 'Звенигород', 'Дмитров', nan, 'Ногинск',
#        'Троицк', 'location', 'Щёлково', 'Королёв', 'Клин', 'Черноголовка',
#        'Видное', 'Волоколамск', 'Талодом', 'Дзержинский', 'Пересвет',
#        'москва', 'Фрязино', 'Шатура', 'Красногорск', 'Мытищи'],
#       dtype=object)

# %%
df
# Out:
#                                  author        author_type  \
# 0                          ID 115709096          homeowner
# 1     Самолёт плюс Подмосковье Серпухов  real_estate_agent
# 2                            ID 3246838            realtor
# 3                           ID 64398571            unknown
# 4                             ЛИДЕРМЭЙН  real_estate_agent
# ...                                 ...                ...
# 8388                              МИЭЛЬ  real_estate_agent
# 8389                                ПИК          developer
# 8390                        ID 47276638          homeowner
# 8391                         EstateLiga  real_estate_agent
# 8392                                ПИК          developer
#
#                                                  url  location deal_type  \
# 0     https://serpukhov.cian.ru/sale/flat/301136001/  Серпухов      sale
# 1     https://serpukhov.cian.ru/sale/flat/305145433/  Серпухов      sale
# 2     https://serpukhov.cian.ru/sale/flat/308145954/  Серпухов      sale
# 3     https://serpukhov.cian.ru/sale/flat/309086009/  Серпухов      sale
# 4     https://serpukhov.cian.ru/sale/flat/308401669/  Серпухов      sale
# ...                                              ...       ...       ...
# 8388  https://mytishchi.cian.ru/sale/flat/308939371/    Мытищи      sale
# 8389  https://mytishchi.cian.ru/sale/flat/306943495/    Мытищи      sale
# 8390  https://mytishchi.cian.ru/sale/flat/294184046/    Мытищи      sale
# 8391  https://mytishchi.cian.ru/sale/flat/304572510/    Мытищи      sale
# 8392  https://mytishchi.cian.ru/sale/flat/303513303/    Мытищи      sale
#
#      accommodation_type floor floors_count rooms_count total_meters  ...  \
# 0                  flat     6            6           1         20.7  ...
# 1                  flat     1            9           1         33.0  ...
# 2                  flat     4            4           1         14.0  ...
# 3                  flat     5            5           1         17.5  ...
# 4                  flat     4            7           1         25.9  ...
# ...                 ...   ...          ...         ...          ...  ...
# 8388               flat     8           14           2         69.7  ...
# 8389               flat    19           25           2         48.1  ...
# 8390               flat     3            5           2         45.0  ...
# 8391               flat     3            6           2         34.0  ...
# 8392               flat     3           16           2         58.6  ...
#
#      finish_type living_meters kitchen_meters        phone ceiling_height  \
# 0             -1         18 м²           1 м²  79175096253            3 м
# 1             -1         18 м²           6 м²  79645530086          2,7 м
# 2             -1            -1             -1  79807126116             -1
# 3             -1            -1             -1  79645652380             -1
# 4             -1         20 м²           5 м²  79099408093          3,5 м
# ...          ...           ...            ...          ...            ...
# 8388          -1         38 м²        10,5 м²  79672094035             -1
# 8389    Чистовая       22,7 м²        16,1 м²  74951370494         2,62 м
# 8390          -1            -1           6 м²  79153266030             -1
# 8391          -1         19 м²           8 м²  79651097781         2,75 м
# 8392    Чистовая       24,9 м²        21,4 м²  74951348120         2,62 м
#
#                      district                street house_number underground  \
# 0                    Серпухов               Крюкова            4         NaN
# 1                         NaN            Ворошилова          144      Аннино
# 2     Красный Текстильщик мкр   Красный Текстильщик            2         NaN
# 3                    Серпухов           Российская            40         NaN
# 4                    Серпухов               Химиков            8         NaN
# ...                       ...                   ...          ...         ...
# 8388                      NaN            Юбилейная             6  Медведково
# 8389                      NaN                   NaN          NaN   Ростокино
# 8390                      NaN            Юбилейная          11к3  Медведково
# 8391                      NaN      бульвар Тенистый            5  Медведково
# 8392                      NaN                   NaN          NaN  Медведково
#
#          residential_complex
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 8388             Ярославский
# 8389  Ярославский квартал ЖК
# 8390                     NaN
# 8391    Императорские Мытищи
# 8392            Яуза Парк ЖК
#
# [7577 rows x 27 columns]

# %%
df.drop( ['author', 'author_type', 'url', 'deal_type', 'accommodation_type', 'phone', 'residential_complex', 'house_number'], axis=1, inplace=True)
