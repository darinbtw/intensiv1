# %%
import pandas as pd #Импортируем библиотеки
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter('ignore')
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn import metrics
from sklearn.preprocessing import scale
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('..\check_data\parsing.csv')

df.head(10)
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2  flat  \
# 0        NaN        NaN        NaN  flat
# 1        NaN        NaN        NaN  flat
# 2        NaN        NaN        NaN  flat
# 3        NaN        NaN        NaN  flat
# 4        NaN        NaN        NaN  flat
# 5        NaN        NaN        NaN  flat
# 6        NaN        NaN        NaN  flat
# 7        NaN        NaN        NaN  flat
# 8        NaN        NaN        NaN  flat
# 9        NaN        NaN        NaN  flat
#
#    {'status': 'discount_received', 'value': 0.3} Unnamed: 5 Unnamed: 6  False  \
# 0  {'status': 'discount_received', 'value': 0.3}        NaN        NaN  False
# 1  {'status': 'discount_received', 'value': 0.3}        NaN        NaN  False
# 2  {'status': 'discount_received', 'value': 0.3}        NaN        NaN  False
# 3     {'status': 'discount_error', 'value': 0.6}        NaN        NaN  False
# 4  {'status': 'discount_received', 'value': 0.6}        NaN        NaN  False
# 5  {'status': 'discount_received', 'value': 0.3}        NaN        NaN  False
# 6  {'status': 'discount_received', 'value': 0.3}        NaN        NaN  False
# 7  {'status': 'discount_received', 'value': 0.3}        NaN        NaN  False
# 8                   {'status': 'discount_error'}        NaN        NaN  False
# 9                   {'status': 'discount_error'}        NaN        NaN  False
#
#           2024-10-10T15:27:21+00:00 Unnamed: 9  ...  \
# 0         2024-03-19T16:07:18+00:00        NaN  ...
# 1  2024-09-30T12:26:02.102638+00:00        NaN  ...
# 2  2024-10-22T16:34:50.173459+00:00        NaN  ...
# 3         2024-10-24T13:28:49+00:00        NaN  ...
# 4         2024-09-23T16:31:18+00:00        NaN  ...
# 5  2024-10-16T18:12:26.584683+00:00        NaN  ...
# 6  2024-09-30T19:07:35.530184+00:00        NaN  ...
# 7  2024-10-19T15:59:39.435160+00:00        NaN  ...
# 8  2024-07-31T04:04:32.603176+00:00        NaN  ...
# 9  2024-06-25T00:53:12.393394+00:00        NaN  ...
#
#    {'agent': {'achievements': {'SER': False, 'SBR': True, 'AGENT_PROFILE': False, 'OFFERS_SALE_COUNT': False, 'CLIENT_REVIEW': False, 'SAFE_DEAL': True, 'DOMCLICK_EXPERT': True, 'NON_MORTGAGE_DEALS': False}, 'person': {'firstname': 'Алеся', 'offers_sale_count': 1, 'sbol_verified_state': 'verified_none', 'lastname': 'Лунина', 'phone': '+7 968 *** ** 56', 'cas_id': 616988, 'created_dt': '2017-05-31T12:01:15.081000+00:00', 'fullname': 'Лунина Алеся Анатольевна', 'patronymic': 'Анатольевна', 'id': 7381763}, 'phone': '+7 968 *** ** 56', 'full_name': 'Алеся', 'cas_id': 616988, 'is_agent': True, 'is_sbol_verified': False, 'show_original_phone': True}, 'company': {'id': 292531, 'legal_name': 'ИП Кононец Владимир Олегович', 'trade_name': 'ИП Кононец Владимир Олегович', 'phone': '+7 903 *** ** 96', 'is_virtual': False, 'is_showcase': True, 'name': 'ИП Кононец Владимир Олегович', 'display_name': 'ИП Кононец Владимир Олегович', 'one_person_business': False}}  \
# 0  {'agent': {'achievements': {}, 'phone': '+7 90...
# 1  {'agent': {'achievements': {'SER': False, 'SBR...
# 2  {'agent': {'achievements': {'SER': False, 'SBR...
# 3  {'agent': {'achievements': {'SER': False, 'SBR...
# 4  {'agent': {'achievements': {'SER': False, 'SBR...
# 5  {'agent': {'achievements': {'SER': False, 'SBR...
# 6  {'agent': {'achievements': {'SER': False, 'SBR...
# 7  {'agent': {'achievements': {'SER': False, 'SBR...
# 8  {'agent': {'achievements': {'SER': False, 'SBR...
# 9  {'agent': {'achievements': {'SER': False, 'SBR...
#
#    False.3  \
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
#
#   {'name': 'top', 'display_name': 'ТОП', 'sort': 2, 'big_card': True, 'pin_color': True}  \
# 0  {'name': 'top', 'display_name': 'ТОП', 'sort':...
# 1  {'name': 'top', 'display_name': 'ТОП', 'sort':...
# 2  {'name': 'top', 'display_name': 'ТОП', 'sort':...
# 3  {'name': 'top', 'display_name': 'ТОП', 'sort':...
# 4  {'name': 'top', 'display_name': 'ТОП', 'sort':...
# 5  {'name': 'top', 'display_name': 'ТОП', 'sort':...
# 6  {'name': 'top', 'display_name': 'ТОП', 'sort':...
# 7  {'name': 'top', 'display_name': 'ТОП', 'sort':...
# 8  {'name': 'top', 'display_name': 'ТОП', 'sort':...
# 9  {'name': 'top', 'display_name': 'ТОП', 'sort':...
#
#    living  True.2  False.4                                        Unnamed: 44  \
# 0  living   False    False                                                NaN
# 1  living     NaN      NaN                                                NaN
# 2  living     NaN      NaN                                                NaN
# 3  living   False    False                                                NaN
# 4  living   False    False  {'id': 115070, 'name': 'ЖК Эвер', 'building': ...
# 5  living     NaN      NaN  {'id': 1832, 'name': 'ЖК "РАССКАЗОVО"', 'build...
# 6  living     NaN      NaN  {'id': 111921, 'name': 'ЖК "КутузовGRAD II (Ку...
# 7  living     NaN      NaN  {'id': 115402, 'name': 'ЖК "Южные сады"', 'bui...
# 8  living     NaN      NaN                                                NaN
# 9  living     NaN      NaN                                                NaN
#
#   Unnamed: 45 Unnamed: 46                                        Unnamed: 47
# 0         NaN         NaN                                                NaN
# 1         NaN         NaN                                                NaN
# 2         NaN         NaN                                                NaN
# 3         NaN         NaN                                                NaN
# 4         NaN         NaN                                                NaN
# 5         NaN         NaN                                                NaN
# 6         NaN         NaN  [{'id': 'LoAkbv0fMOk', 'url': 'https://www.you...
# 7         NaN         NaN                                                NaN
# 8         NaN         NaN                                                NaN
# 9         NaN         NaN                                                NaN
#
# [10 rows x 48 columns]
