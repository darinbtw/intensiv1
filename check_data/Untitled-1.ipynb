# %%
import pandas as pd #Импортируем библиотеки
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter('ignore')
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn import metrics
from sklearn.preprocessing import scale
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('..\check_data\zxc.csv')

df.head(10)
# Out:
#      Unnamed: 0         Unnamed: 1  \
# 0  ID 102339337          homeowner
# 1   ID 67474576            realtor
# 2           NaN                NaN
# 3  Этажи Москва  real_estate_agent
# 4      ID 31556            realtor
# 5           NaN                NaN
# 6  Этажи Москва  real_estate_agent
# 7   ID 89919508            unknown
# 8           NaN                NaN
# 9  ID 119235442          homeowner
#
#    https://dolgoprudny.cian.ru/sale/flat/294460563/  Долгопрудный  sale  flat  \
# 0  https://dolgoprudny.cian.ru/sale/flat/306701329/  Долгопрудный  sale  flat
# 1  https://dolgoprudny.cian.ru/sale/flat/294527055/  Долгопрудный  sale  flat
# 2  https://dolgoprudny.cian.ru/sale/flat/309057311/  Долгопрудный  sale  flat
# 3  https://dolgoprudny.cian.ru/sale/flat/308568163/  Долгопрудный  sale  flat
# 4  https://dolgoprudny.cian.ru/sale/flat/308781051/  Долгопрудный  sale  flat
# 5  https://dolgoprudny.cian.ru/sale/flat/306627927/  Долгопрудный  sale  flat
# 6  https://dolgoprudny.cian.ru/sale/flat/307662825/  Долгопрудный  sale  flat
# 7  https://dolgoprudny.cian.ru/sale/flat/303906099/  Долгопрудный  sale  flat
# 8  https://dolgoprudny.cian.ru/sale/flat/306627897/  Долгопрудный  sale  flat
# 9  https://dolgoprudny.cian.ru/sale/flat/304961831/  Долгопрудный  sale  flat
#
#    13  23  1  42.0  ...  Unnamed: 15    Хлебниково       Бригантина ЖК  \
# 0   5   5  1  32.0  ...         43к2  Долгопрудная                 NaN
# 1  20  21  1  40.0  ...           11       Водники  Московские водники
# 2   9  23  1  34.5  ...          NaN    Хлебниково       Бригантина ЖК
# 3   9  18  1  44.0  ...         56к3       Водники  Московские водники
# 4   3  16  1  35.0  ...           17       Водники                 NaN
# 5   7  23  1  33.6  ...          NaN    Хлебниково       Бригантина ЖК
# 6   6  23  1  49.5  ...           17       Водники  Московские водники
# 7   4  23  1  30.0  ...         52к1       Водники          Бригантина
# 8  14  23  1  32.6  ...          NaN    Хлебниково       Бригантина ЖК
# 9  24  26  1  49.0  ...         80к1  Долгопрудная                 NaN
#
#    Не указано Не указано.1 Не указано.2 Не указано.3 Не указано.4  \
# 0  Не указано   Не указано   Не указано   Не указано   Не указано
# 1  Не указано   Не указано   Не указано   Не указано   Не указано
# 2  Не указано   Не указано   Не указано   Не указано   Не указано
# 3  Не указано   Не указано   Не указано   Не указано   Не указано
# 4  Не указано   Не указано   Не указано   Не указано   Не указано
# 5  Не указано   Не указано   Не указано   Не указано   Не указано
# 6  Не указано   Не указано   Не указано   Не указано   Не указано
# 7  Не указано   Не указано   Не указано   Не указано   Не указано
# 8  Не указано   Не указано   Не указано   Не указано   Не указано
# 9  Не указано   Не указано   Не указано   Не указано   Не указано
#
#   Не указано.5 Не указано.6
# 0   Не указано   Не указано
# 1   Не указано   Не указано
# 2   Не указано   Не указано
# 3   Не указано   Не указано
# 4   Не указано   Не указано
# 5   Не указано   Не указано
# 6   Не указано   Не указано
# 7   Не указано   Не указано
# 8   Не указано   Не указано
# 9   Не указано   Не указано
#
# [10 rows x 25 columns]
